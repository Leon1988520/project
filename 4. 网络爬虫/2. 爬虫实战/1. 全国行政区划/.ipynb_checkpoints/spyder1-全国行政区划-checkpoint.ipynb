# %% [markdown]
# # 爬取全国行政区划
#
#
# 1. 网站地址[http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/index.html](http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/index.html)
#
#
# ## 爬取策略
# 1. 爬取主页数据，将链接数据入队
# 2. 在队列中，依次拿出各网址，爬取该网址的数据，入队
# 3. 每一页中，逐行将链接的文字，放入数据库中
#
#
# ## 知识点
# 1. requests
# 2. beautifulsoup
#     - soup.select('tr[class="villagetr"]')
#     - soup.find_all("a")
#
# 3. 爬虫攻防：构建头
#
#
# ## 参考
# 1. [python简单爬虫](http://cache.baiducontent.com/c?m=9d78d513d9810ae902b0c8690d67c0171e43f1612ba7d10208d08448e2320c1e1a72a4fb792d4a4295873d7000dc5441afb57365377471ebcb96d51f9cac925f7ed57829234cd11f539404edd64126c327975ce9b81990e0b66dcd&p=b4769a4786cc4ae000a48e2c4f&newp=82769a47928911a053a4d6275953d8224216ed623fd4c44324b9d71fd325001c1b69e7bc2d261702d4c4796d0bad4d5aeef63078341766dada9fca458ae7c46c65&user=baidu&fm=sc&query=python+%C5%C0%B3%E6+demo&qid=bd8c9e6500034ce3&p1=2)
# 2. [1个小白五小时的爬虫经历](https://www.cnblogs.com/panzi/p/6421826.html)
# 3. [32个爬虫项目-让你一次吃到饱](https://blog.csdn.net/qq_41396296/article/details/79428834)

# %%
# 引入库
import requests
import re
import pandas as pd
import time
import random
from bs4 import BeautifulSoup


dir_base = "http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017"

# %%
# 获得html文档
def get_html(url):
    """get the content of the url"""
    session = requests.Session()
    
    header = {
#         "User-Agent":"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.82 Safari/537.36"
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
        ,'Referer':'http://www.stats.gov.cn/'
    }
    res = session.get(url, headers=header, timeout = 50000)
    res.encoding = "gb2312"
    return BeautifulSoup(res.text)

soup = get_html("%s/%s" %(dir_base, "62/09/22/620922215.html"))
soup.select("a")
# Out:
# D:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file D:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# [<a class="STYLE3" href="http://www.miibeian.gov.cn/" target="_blank">京ICP备05034670号</a>]

# %%
len(soup.find_all("a"))
# Out:
# 1

# %%
for link in soup.select('tr[class="villagetr"]'):
    print(link.find_all("td")[2].get_text())
# Out:
# 常顺村委会
# 沙河村委会
# 临河村委会
# 民和村委会
# 河洲村委会

# %%
# %%time
# 地址格式(五级)
# 省 市 区/县 乡镇/街道 居委会
"""
算法：
    1. 创建一个行标，一个空数组，用于存放行政区划
    2. 从根路径index开始，采用深度优先搜索策略
        爬取当前页面，如果当前页面有链接，则压入栈内
                      如果当前页面没有链接(除了外链)，即已经爬到了末端，将该页面的内容写入行政区划表，row+1
        取栈中的下一个地址
            如果栈中记录的不是地址，那么row-1，并在对应列中写入栈中记入的数据，row+1
            取栈中的下一个地址
    3. 空值填充，后向填充
"""
row = 0
df_district = pd.DataFrame()

html_list = [{"url":"%s/%s" %(dir_base, "index.html")}]

f = open(r"E:\workspace\0. git\project\4. 网络爬虫\2. 爬虫实战\1. 全国行政区划\addr.txt", "w")

while len(html_list) > 0:
    time.sleep(random.random())   # 休眠随机秒(0-1秒)
    node = html_list.pop()
    if "url" in list(node.keys()):
        url = node["url"]
    else:
        key_no = node["key_no"]
        value_no = node["value_no"]
        tag = node["tag"]
        value_tag = node["value_tag"]
        
        row -= 1
        df_district.loc[row, key_no] = value_no
        df_district.loc[row, tag] = value_tag
        row += 1
        continue
    
    soup = get_html(url)
    # 如果找到a
    if len(soup.find_all("a")) == 1: # 如果找到的a标签只有1个，即[<a class="STYLE3" href="http://www.miibeian.gov.cn/" target="_blank">京ICP备05034670号</a>]，表示爬到了末端
        for link in soup.select('tr[class="villagetr"]'):
            df_district.loc[row, "v_no"] = link.find_all("td")[1].get_text()
            df_district.loc[row, "village"] = link.find_all("td")[2].get_text()
            
#             df_district.loc[row, "t_no"] = link.find_all("td")[1].get_text()
#             df_district.loc[row, "town"] = link.find_all("td")[2].get_text()
            
            row += 1
        continue
        
    for link in soup.find_all("a"):
        html = link.get("href")
        tag = link.get_text()
        
        if html.startswith("http") == False and re.match(r"\d+", tag) is None:
            if len(html) == 7:
                html_list.append({"tag":"province", "value_tag":tag, "key_no":"p_no", "value_no":html[:2]})
                r = "%s/%s" %(dir_base, html)
            elif len(html) == 12:
                html_list.append({"tag":"city", "value_tag":tag, "key_no":"c_no", "value_no":html[3:7]})
                r = "%s/%s" %(dir_base, html)
            elif len(html) == 14:
                html_list.append({"tag":"district", "value_tag":tag, "key_no":"d_no", "value_no":html[3:9]})
                r = "%s/%s/%s" %(dir_base, html[3:5], html)
            elif len(html) == 17:
                html_list.append({"tag":"town", "value_tag":tag, "key_no":"t_no", "value_no":html[3:12]})
                r = "%s/%s/%s/%s" %(dir_base, html[3:5], html[5:7], html)
                
            html_list.append({"url":r})
            f.write("%s\n" %(r))
f.close()
# Out:
# D:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file D:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      97     if err is not None:
# ---> 98         raise err
#      99
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     362         else:
# --> 363             conn.request(method, url, **httplib_request_kw)
#     364
#
# D:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# D:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# D:\Anaconda3\lib\http\client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# D:\Anaconda3\lib\http\client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# D:\Anaconda3\lib\http\client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     150             raise NewConnectionError(
# --> 151                 self, "Failed to establish a new connection: %s" % e)
#     152
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x00000289CE986DD8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     639             retries = retries.increment(method, url, error=e, _pool=self,
# --> 640                                         _stacktrace=sys.exc_info()[2])
#     641             retries.sleep()
#
# D:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     286         if new_retry.is_exhausted():
# --> 287             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     288
#
# MaxRetryError: HTTPConnectionPool(host='www.stats.gov.cn', port=80): Max retries exceeded with url: /tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/28/654028205.html (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x00000289CE986DD8>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-f432c89c7a97> in <module>()
#      37         continue
#      38
# ---> 39     soup = get_html(url)
#      40     # 如果找到a
#      41     if len(soup.find_all("a")) == 1: # 如果找到的a标签只有1个，即[<a class="STYLE3" href="http://www.miibeian.gov.cn/" target="_blank">京ICP备05034670号</a>]，表示爬到了末端
#
# <ipython-input-2-6c3bf9b9be9c> in get_html(url)
#       8         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'
#       9     }
# ---> 10     res = session.get(url, headers=header, timeout = 50000)
#      11     res.encoding = "gb2312"
#      12     return BeautifulSoup(res.text)
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     486
#     487         kwargs.setdefault('allow_redirects', True)
# --> 488         return self.request('GET', url, **kwargs)
#     489
#     490     def options(self, url, **kwargs):
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# D:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www
'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/44.html'},
#  {'key_no': 'p_no',
#   'tag': 'province',
#   'value_no': '45',
#   'value_tag': '广西壮族自治区'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/45.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '46', 'value_tag': '海南省'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/46.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '50', 'value_tag': '重庆市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/50.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '51', 'value_tag': '四川省'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/51.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '52', 'value_tag': '贵州省'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/52.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '53', 'value_tag': '云南省'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/53.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '54', 'value_tag': '西藏自治区'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/54.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '61', 'value_tag': '陕西省'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/61.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '62', 'value_tag': '甘肃省'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/62.html'},
#  {'key_no': 'p_no', 'tag': 'province', 'value_no': '63', 'value_tag': '青海省'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/63.html'},
#  {'key_no': 'p_no',
#   'tag': 'province',
#   'value_no': '64',
#   'value_tag': '宁夏回族自治区'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/64.html'},
#  {'key_no': 'p_no',
#   'tag': 'province',
#   'value_no': '65',
#   'value_tag': '新疆维吾尔自治区'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6501', 'value_tag': '乌鲁木齐市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6501.html'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6502', 'value_tag': '克拉玛依市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6502.html'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6504', 'value_tag': '吐鲁番市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6504.html'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6505', 'value_tag': '哈密市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6505.html'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6523', 'value_tag': '昌吉回族自治州'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6523.html'},
#  {'key_no': 'c_no',
#   'tag': 'city',
#   'value_no': '6527',
#   'value_tag': '博尔塔拉蒙古自治州'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6527.html'},
#  {'key_no': 'c_no',
#   'tag': 'city',
#   'value_no': '6528',
#   'value_tag': '巴音郭楞蒙古自治州'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6528.html'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6529', 'value_tag': '阿克苏地区'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6529.html'},
#  {'key_no': 'c_no',
#   'tag': 'city',
#   'value_no': '6530',
#   'value_tag': '克孜勒苏柯尔克孜自治州'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6530.html'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6531', 'value_tag': '喀什地区'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6531.html'},
#  {'key_no': 'c_no', 'tag': 'city', 'value_no': '6532', 'value_tag': '和田地区'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/6532.html'},
#  {'key_no': 'c_no',
#   'tag': 'city',
#   'value_no': '6540',
#   'value_tag': '伊犁哈萨克自治州'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654002',
#   'value_tag': '伊宁市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654002.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654003',
#   'value_tag': '奎屯市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654003.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654004',
#   'value_tag': '霍尔果斯市'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654004.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654021',
#   'value_tag': '伊宁县'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654021.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654022',
#   'value_tag': '察布查尔锡伯自治县'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654022.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654023',
#   'value_tag': '霍城县'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654023.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654024',
#   'value_tag': '巩留县'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654024.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654025',
#   'value_tag': '新源县'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654025.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654026',
#   'value_tag': '昭苏县'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654026.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654027',
#   'value_tag': '特克斯县'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/654027.html'},
#  {'key_no': 'd_no',
#   'tag': 'district',
#   'value_no': '654028',
#   'value_tag': '尼勒克县'},
#  {'key_no': 't_no',
#   'tag': 'town',
#   'value_no': '654028100',
#   'value_tag': '尼勒克镇'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/28/654028100.html'},
#  {'key_no': 't_no',
#   'tag': 'town',
#   'value_no': '654028200',
#   'value_tag': '苏布台乡'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/28/654028200.html'},
#  {'key_no': 't_no',
#   'tag': 'town',
#   'value_no': '654028201',
#   'value_tag': '喀拉苏乡'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/28/654028201.html'},
#  {'key_no': 't_no',
#   'tag': 'town',
#   'value_no': '654028202',
#   'value_tag': '加哈乌拉斯台乡'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/28/654028202.html'},
#  {'key_no': 't_no',
#   'tag': 'town',
#   'value_no': '654028203',
#   'value_tag': '尼勒克县乌赞乡'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/28/654028203.html'},
#  {'key_no': 't_no',
#   'tag': 'town',
#   'value_no': '654028204',
#   'value_tag': '科克浩特浩尔蒙古民族乡'},
#  {'url': 'http://www.stats.gov.cn/tjsj/tjbz/tjyqhdmhcxhfdm/2017/65/40/28/654028204.html'},
#  {'key_no': 't_no',
#   'tag': 'town',
#   'value_no': '654028205',
#   'value_tag': '乌拉斯台乡'}]
